# %% [markdown]
# <a href="https://colab.research.google.com/github/omj3424/Python_Programming_Study/blob/main/pandas_exercises/05_Merge/Housing%20Market/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Housing Market

# %% [markdown]
# ### Introduction:
#
# This time we will create our own dataset with fictional numbers to describe a house market. As we are going to create random data don't try to reason of the numbers.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create 3 differents Series, each of length 100, as follows:
# 1. The first a random number from 1 to 4
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000

# %%
df1 = pd.Series(np.random.randint(1, 4, 100))
df2 = pd.Series(np.random.randint(1, 3, 100))
df3 = pd.Series(np.random.randint(10000, 30000, 100))

# %% [markdown]
# ### Step 3. Let's create a DataFrame by joinning the Series by column

# %%
df = pd.concat([df1, df2, df3], axis=1)
df
# Out:
#     0  1      2
# 0   1  1  12184
# 1   1  2  29152
# 2   3  2  27090
# 3   1  1  13632
# 4   3  2  28411
# .. .. ..    ...
# 95  2  2  15253
# 96  2  2  15363
# 97  1  2  20843
# 98  3  2  16678
# 99  1  2  24702
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            12184
# 1       1       2            29152
# 2       3       2            27090
# 3       1       1            13632
# 4       3       2            28411
# ..    ...     ...              ...
# 95      2       2            15253
# 96      2       2            15363
# 97      1       2            20843
# 98      3       2            16678
# 99      1       2            24702
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([df1, df2, df3])
bigcolumn
# Out:
# 0         1
# 1         1
# 2         3
# 3         1
# 4         3
#       ...
# 95    15253
# 96    15363
# 97    20843
# 98    16678
# 99    24702
# Length: 300, dtype: int64

# %% [markdown]
# ### Step 6. Oops, it seems it is going only until index 99. Is it true?

# %%
bigcolumn.shape[0]
# Out:
# 300

# %% [markdown]
# ### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(drop=True, inplace=True)

# drop: 제거한 인덱스를 열에 추가할지 여부

# %%
bigcolumn
# Out:
# 0          1
# 1          1
# 2          3
# 3          1
# 4          3
#        ...
# 295    15253
# 296    15363
# 297    20843
# 298    16678
# 299    24702
# Length: 300, dtype: int64
