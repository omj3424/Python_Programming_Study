# %% [markdown]
# <a href="https://colab.research.google.com/github/omj3424/Python_Programming_Study/blob/main/pandas_exercises/07_Visualization/Titanic_Desaster/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv'

titanic = pd.read_csv(url)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index(keys='PassengerId', inplace=True)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
proportions = titanic.value_counts('Sex')

plt.pie(proportions, labels=['Males', 'Females'],explode=(0.15, 0), startangle=90, autopct='%.1f%%')
plt.title('Sex Proportion')


# explode: 공간을 띄워줌
# startangle: 시작 지점을 설정할 수 있음.



## 다른 방법(feat. 답지)
# males = (titanic.Sex == 'male').sum()
# females = (titanic.Sex == 'female').sum()

# proportions = [males, females]

# plt.pie(proportions, labels=['Males', 'Females'], autopct='%.1f%%')
# plt.title('Sex Proportion')
# Out:
# Text(0.5, 1.0, 'Sex Proportion')

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
a = sns.scatterplot(x=titanic.Age, y=titanic.Fare, hue=titanic.Sex)
a.set(title='Fare x Age', ylim=(0, 600))
# Out:
# [Text(0.5, 1.0, 'Fare x Age'), (0.0, 600.0)]

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic.Survived.sum()
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
payed = sns.histplot(titanic.Fare)
payed.set(title='Fare Price Histogram', xlim=(0, 600), ylim=(0, 350), ylabel='Frequency')
# Out:
# [Text(0.5, 1.0, 'Fare Price Histogram'),
#  (0.0, 600.0),
#  (0.0, 350.0),
#  Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ### BONUS: Create your own question and answer it.
