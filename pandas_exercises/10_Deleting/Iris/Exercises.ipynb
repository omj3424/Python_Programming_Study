# %% [markdown]
# <a href="https://colab.research.google.com/github/omj3424/Python_Programming_Study/blob/main/pandas_exercises/10_Deleting/Iris/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

iris = pd.read_csv(url, sep=',')
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

iris = iris.set_axis(labels=['speal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], axis=1)
iris

# 다른 방법:
# iris.columns = ['sepal_length','sepal_width', 'petal_length', 'petal_width', 'class']
# Out:
#      speal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isna()

# iris.isnull().sum()
# isnull과 isna는 같은 것
# Out:
#      speal_length  sepal_width  petal_length  petal_width  class
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 144         False        False         False        False  False
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29, ['petal_length']] = np.nan

# %%
iris.head(31)
# Out:
#     speal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.petal_length = iris.petal_length.fillna(1.0)

# %%
iris.head(31)
# Out:
#     speal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           1.0          0.2  Iris-setosa
# 11           4.8          3.0           1.0          0.1  Iris-setosa
# ...

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris = iris.drop(columns='class')

# %%
iris
# Out:
#      speal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             4.7          3.2           1.3          0.2
# 2             4.6          3.1           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.loc[:2] = np.nan

# %%
iris
# Out:
#      speal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1             NaN          NaN           NaN          NaN
# 2             NaN          NaN           NaN          NaN
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris = iris.dropna(axis=0)

# %%
iris
# Out:
#      speal_length  sepal_width  petal_length  petal_width
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# 5             4.6          3.4           1.4          0.3
# 6             5.0          3.4           1.5          0.2
# 7             4.4          2.9           1.4          0.2
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True)
# Out:
#      speal_length  sepal_width  petal_length  petal_width
# 0             5.0          3.6           1.4          0.2
# 1             5.4          3.9           1.7          0.4
# 2             4.6          3.4           1.4          0.3
# 3             5.0          3.4           1.5          0.2
# 4             4.4          2.9           1.4          0.2
# ..            ...          ...           ...          ...
# 141           6.7          3.0           5.2          2.3
# 142           6.3          2.5           5.0          1.9
# 143           6.5          3.0           5.2          2.0
# 144           6.2          3.4           5.4          2.3
# 145           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.
